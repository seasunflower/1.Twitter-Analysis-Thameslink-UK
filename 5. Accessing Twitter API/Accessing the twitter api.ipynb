# %%
import tweepy
 
# API keyws that yous saved earlier
api_key = ""
api_secrets = ""
access_token = ""
access_secret = ""
 
# Authenticate to Twitter
auth = tweepy.OAuthHandler(api_key,api_secrets)
auth.set_access_token(access_token,access_secret)
 
api = tweepy.API(auth)

try:
    api.verify_credentials()
    print('Successful Authentication')
except:
    print('Failed authentication')
# Out:
# Successful Authentication

# %%
# Python Script to Extract tweets of a
# particular Hashtag using Tweepy and Pandas
 
# import modules
import pandas as pd
import tweepy
 
# function to display data of each tweet
def printtweetdata(n, ith_tweet):
        print()
        print(f"Tweet {n}:")
        print(f"Username:{ith_tweet[0]}")
        print(f"Description:{ith_tweet[1]}")
        print(f"Location:{ith_tweet[2]}")
        print(f"Following Count:{ith_tweet[3]}")
        print(f"Follower Count:{ith_tweet[4]}")
        print(f"Total Tweets:{ith_tweet[5]}")
        print(f"Retweet Count:{ith_tweet[6]}")
        print(f"Tweet Text:{ith_tweet[7]}")
        print(f"Hashtags Used:{ith_tweet[8]}")
        print(f"Place:{ith_tweet[9]}")
        print(f"Geoe:{ith_tweet[10]}")
 
 
# function to perform data extraction
def scrape(words, date_since, numtweet):
 
        # Creating DataFrame using pandas
        db = pd.DataFrame(columns=['username',
                                   'description',
                                   'location',
                                   'following',
                                   'followers',
                                   'totaltweets',
                                   'retweetcount',
                                   'text',
                                   'hashtags','place',"geoe"])
 
        # We are using .Cursor() to search
        # through twitter for the required tweets.
        # The number of tweets can be
        # restricted using .items(number of tweets)
        tweets = tweepy.Cursor(api.search_tweets,
                               words, lang="en",
                               since_id=date_since,
                               tweet_mode='extended').items(numtweet)
 
 
        # .Cursor() returns an iterable object. Each item in
        # the iterator has various attributes
        # that you can access to
        # get information about each tweet
        list_tweets = [tweet for tweet in tweets]
 
        # Counter to maintain Tweet Count
        i = 1
 
        # we will iterate over each tweet in the
        # list for extracting information about each tweet
        for tweet in list_tweets:
                username = tweet.user.screen_name
                description = tweet.user.description
                location = tweet.user.location
                place = tweet.place
                following = tweet.user.friends_count
                followers = tweet.user.followers_count
                totaltweets = tweet.user.statuses_count
                retweetcount = tweet.retweet_count
                hashtags = tweet.entities['hashtags']
                geoe = tweet.user.geo_enabled
 
                # Retweets can be distinguished by
                # a retweeted_status attribute,
                # in case it is an invalid reference,
                # except block will be executed
                try:
                        text = tweet.retweeted_status.full_text
                except AttributeError:
                        text = tweet.full_text
                hashtext = list()
                for j in range(0, len(hashtags)):
                        hashtext.append(hashtags[j]['text'])
 
                # Here we are appending all the
                # extracted information in the DataFrame
                ith_tweet = [username, description,
                             location,following,
                             followers, totaltweets,
                             retweetcount, text, hashtext,place,geoe]
                db.loc[len(db)] = ith_tweet
 
                # Function call to print tweet data on screen
                printtweetdata(i, ith_tweet)
                i = i+1
        filename = 'scraped_tweets1.xlsx'
 
        # we will save our database as a CSV file.
        db1 = db[["text","location","place"]]
        db1.to_excel(filename)
 
if __name__ == '__main__':
 
        # Enter your own credentials obtained
        # from your developer account
        consumer_key = ""
        consumer_secret = ""
        access_key = ""
        access_secret = ""
 
 
        auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
        auth.set_access_token(access_key, access_secret)
        api = tweepy.API(auth)
 
        # Enter Hashtag and initial date
        print("Enter Twitter HashTag to search for")
        words = input()
        print("Enter Date since The Tweets are required in yyyy-mm--dd")
        date_since = input()
 
        # number of tweets you want to extract in one run
        numtweet = 1000
        scrape(words, date_since, numtweet)
        print('Scraping has completed!')
# Out:
# Enter Twitter HashTag to search for
# thameslink
# Enter Date since The Tweets are required in yyyy-mm--dd
# 2022-11-21
#
# Tweet 1:
# Username:dt_dwh
# Description:
# Location:
# Following Count:297
# Follower Count:201
# Total Tweets:1915
# Retweet Count:0
# Tweet Text:@BeeRowlatt @GC_Rail @TLRailUK Ah, copying The Thameslink trademark #thameslink Mile for mile, probably far more expensive on Thameslink https://t.co/dzBfeMXpGV
# Hashtags Used:['thameslink']
# Place:None
# Geoe:True
#
# Tweet 2:
# Username:jacquidarlow
# Description:Digital Product Lead @dogstrust, Cats, McLaren F1, chocolate and cycling. This is me... #cyclesafe #papaya
# Location:London
# Following Count:2544
# Follower Count:1930
# Total Tweets:15784
# Retweet Count:0
# Tweet Text:@EastMidRailway well thats not helpful I need to travel on the 26th, thameslink is running , can I get refund...?
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 3:
# Username:c_zyexn
# Description:💜Bandidap de corazón 😈🤙🏻|🇪🇨🦁
# Location:Oman
# Following Count:10
# Follower Count:0
# Total Tweets:4
# Retweet Count:0
# Tweet Text:📢 Due to availability of rail replacement vehicles, a limited bus service will be running this morning on the following routes:
#
# 👉 Between Luton and Harpenden
# 👉 Between West Hampstead Thameslink and Harpenden
#
# Please check before you travel here👇
# https://t.co/CmYlTChaVr
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 4:
# Username:alextyler0206
# Description:if you see this HB, SB, MB. I’m sorry
# Location:
# Following Count:0
# Follower Count:2
# Total Tweets:734
# Retweet Count:0
# Tweet Text:@_LimeAID how am I meant to get on/ busses that stop at this bus stop, City Thameslink station Ludgate hill exit. https://t.co/2Ngs82xWIF
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 5:
# Username:TLRailUK
# Description:Hello from Thameslink 👋! Taking you across London and beyond; we're here to help 24 hours a day, 7 days a week.
# Location:UK
# Following Count:263
# Follower Count:91806
# Total Tweets:341953
# Retweet Count:0
# Tweet Text:@Meloney007 @Se_Railway Hi there, Thameslink are not on strike on the 26th November. We would always advise checking journey planners before travelling. Thanks ^Scottie
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 6:
# Username:zoekennedy
# Description:All views my own. Humourless feminist - what did you just say?
# Location:London
# Following Count:4585
# Follower Count:1475
# Total Tweets:24869
# Retweet Count:0
# Tweet Text:I think I’m annoyed by the presumption that the issue is me being stupid and not terrible equipment. I’m also annoyed that every time I’m at the station I have to yell down for the staff to come up. The equipment is terrible, fix it Thameslink.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 7:
# Username:nationalrailenq
# Description:24/7 support across the National Rail network. Real time updates and advice on services provided. All DMs deleted after 30 days of conversation ending.
# Location:Great Britain
# Following Count:377
# Follower Count:1061854
# Total Tweets:700606
# Retweet Count:0
# Tweet Text:🎟️#SurreyQuays - To assist with your journey, you may use your ticket with the following operators:
# -Greater Anglia
# -Great Northern
# -Southeastern
# -Southern
# -South Western Railway
# -Elizabeth line
# -Thameslink
# Hashtags Used:['SurreyQuays']
# Place:None
# Geoe:False
#
# Tweet 8:
# Username:littledroidNE
# Description:yo, its lasagna not shish kebab
# Location:she her 16 fan account
# Following Count:1408
# Follower Count:1607
# Total Tweets:65731
# Retweet Count:0
# Tweet Text:guys i’m slightly nervous because there is a train to king’s cross at the right platform but it’s a great northern train not thameslink and mine is supposed to be thameslink
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 9:
# Username:TrainBeacon
# Description:📱Mobile app. Shows estimated UK train positions in augmented reality and on map
# Location:🚉 🍏App Store & Google Play
# Following Count:5708
# Follower Count:5320
# Total Tweets:369271
# Retweet Count:0
# Tweet Text:Thameslink update: Due to an earlier signalling problem that needed to be investigated at London Blackfriars: https://t.co/gN68Pcu9ZA
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 10:
# Username:nickbeddows
# Description:Only connect. Using digital media to tell stories and engage people.
# Location:#Brighton #Abruzzo #London
# Following Count:1810
# Follower Count:1761
# Total Tweets:115975
# Retweet Count:0
# Tweet Text:@MmmmTrams @greghove Having stood from London Bridge to Brighton many many times, I'd question Thameslink's capacity to absorb overcrowding whenever there's a ripple in the timetable
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 11:
# Username:john_jones7
# Description:Retired teacher. (Bath / Wilts.)
# UCNW Bangor. (Physics / ODA)
# Location:Lancashire, U.K.
# Following Count:4847
# Follower Count:2436
# Total Tweets:31120
# Retweet Count:1
# Tweet Text:Am going to see my mum in Hertford on Saturday via Thameslink and great northern and luckily these services aren’t on strike that day but most of the others are. It’s going to be carnage isn’t it?
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 12:
# Username:Se_Railway
# Description:Providing real-time information about Southeastern services 24/7. For comments, complaints, & fares information, please visit our website or call 0345 322 7021
# Location:London, Kent and East Sussex
# Following Count:132
# Follower Count:247003
# Total Tweets:781789
# Retweet Count:0
# Tweet Text:@Michael35427696 Hi, Engineers are onsite and working to rectify the fault, ticket acceptance is in place:
# Buses between Hayes and Lewisham
# Tramlink: Elmers End - East Croydon
# Thameslink: Easter Croydon - London.
#
# ^OS
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 13:
# Username:MmmmTrams
# Description:Love long distance train and ferry travel, trams, buses and anything that moves. Retired Controller for UK TOC. Left wing, proud Rejoiner ☺️
# Location:East Kent
# Following Count:3378
# Follower Count:4265
# Total Tweets:111148
# Retweet Count:0
# Tweet Text:@greghove No it shouldn’t be. Thameslink trains have huge capacity to absorb passengers for any overcrowding and NR aren’t affected
# Hashtags Used:[]
# Place:Place(_api=<tweepy.api.API object at 0x000001615AF5A280>, id='29ac72e481808450', url='https://api.twitter.com/1.1/geo/id/29ac72e481808450.json', place_type='city', name='Slough', full_name='Slough, South East', country_code='GB', country='United Kingdom', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000001615AF5A280>, type='Polygon', coordinates=[[[-0.660061, 51.4904842], [-0.5251377, 51.4904842], [-0.5251377, 51.538905], [-0.660061, 51.538905]]]), attributes={})
# Geoe:True
#
# Tweet 14:
# Username:greghove
# Description:50 something chef. born hackney so forever a cockney. laugh, love, live. follow and dm gets blocked . 23 favourite number. double simian. saggi. GAY!
# Location:hove uk
# Following Count:7419
# Follower Count:7354
# Total Tweets:70389
# Retweet Count:1
# Tweet Text:Am going to see my mum in Hertford on Saturday via Thameslink and great northern and luckily these services aren’t on strike that day but most of the others are. It’s going to be carnage isn’t it?
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 15:
# Username:Se_Railway
# Description:Providing real-time information about Southeastern services 24/7. For comments, complaints, & fares information, please visit our website or call 0345 322 7021
# Location:London, Kent and East Sussex
# Following Count:132
# Follower Count:247003
# Total Tweets:781789
# Retweet Count:0
# Tweet Text:⚠️ONGOING: #Hayes
# ❌No service between Hayes and Elmers End.
# ❌Trains towards London also cannot stop at Lower Sydenham.
# 🎫Tickets accepted on the following:
# 🚌London Buses Hayes - Lewisham
# 🚋Tramlink services Elmers End - East Croydon
# 🚆Thameslink services East Croydon - London
# Hashtags Used:['Hayes']
# Place:None
# Geoe:True
#
# Tweet 16:
# Username:mariaakin8
# Description:follow my backup @AkinkuolieMaria she/her https://t.co/X0uqiVW11Q
# Location:
# Following Count:1456
# Follower Count:762
# Total Tweets:46398
# Retweet Count:0
# Tweet Text:@thegirlinlust That’s true :/ you can always rely on thameslink to get you there when they say they will
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 17:
# Username:thegirlinlust
# Description:༺♡︎༻ https://t.co/sGDKUKsuqS
# Location:london
# Following Count:475
# Follower Count:51766
# Total Tweets:56363
# Retweet Count:0
# Tweet Text:@mariaakin8 thameslink is slow but all of the overground ones are
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 18:
# Username:thegirlinlust
# Description:༺♡︎༻ https://t.co/sGDKUKsuqS
# Location:london
# Following Count:475
# Follower Count:51766
# Total Tweets:56363
# Retweet Count:0
# Tweet Text:@mariaakin8 thameslink &gt;&gt;
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 19:
# Username:BillaSingh10
# Description:macho moustache
# Location:various
# Following Count:245
# Follower Count:28
# Total Tweets:329
# Retweet Count:0
# Tweet Text:Hello @TLRailUK I need to apply for a refund for a difference in my ticket price as I forgot my network railcard. Can this be done at a Thameslink station or can I apply online - I cannot find any relevant form online for this
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 20:
# Username:ShepheardDavid
# Description:A Spelljammer fan seeking other Spelljammer fans on Twitter.
#
# I play Braxon Miacc in @AuldDragon's live-streamed Spelljammer game on Twitch.
# Location:London, England
# Following Count:304
# Follower Count:248
# Total Tweets:7449
# Retweet Count:0
# Tweet Text:@JenOnTheMoveUK @GarethDennis In London, we have made a couple of mistakes:
# • Tiny loading gauge on tube lines and
# • Non-level boarding compliance for both Thameslink and Crossrail platform heights.
#
# It's essential that we don't bake in mistakes in other cities.
#
# 2/2
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 21:
# Username:DavidMuttering
# Description:Mixing up a spot of bewigged law with some quality lounging, #pvfc, awkward puns and tireless pedantry.
# Location:
# Following Count:787
# Follower Count:32190
# Total Tweets:57610
# Retweet Count:0
# Tweet Text:@GreatStrides65 I am. That just came up on the search. A more tube orientated site has it at 30 mins, which is about right - getting to Earls Court is nearly 20 from Wimbledon. If there’s no Edgware Road train for a while the hipsters route is Thameslink / Elizabeth line via Farringdon. https://t.co/m7r4IO4rBd
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 22:
# Username:cmpd_date
# Description:Visit my Flickr for latest photos. 👇📸
# Location:Plumpton, East Sussex
# Following Count:0
# Follower Count:394
# Total Tweets:40
# Retweet Count:0
# Tweet Text:@JamessyBoii95 @EthanAfro @SouthernRailUK @DispatcherBML @ElliottBirdDJ Because it was a crappy Thameslink unit, I avoid them like the plague. Plus I rarely get 377/3 haulage, even rarer on the mainline.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 23:
# Username:CoyModemKnight
# Description:
# Location:
# Following Count:46
# Follower Count:241
# Total Tweets:30165
# Retweet Count:0
# Tweet Text:@EmanuelaPerill2 Your train has been late 63% of the time over the last 12 weeks, but it's not the worst! Performance for Thameslink to be proud of! https://t.co/3mKXWVGMea
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 24:
# Username:nationalrailenq
# Description:24/7 support across the National Rail network. Real time updates and advice on services provided. All DMs deleted after 30 days of conversation ending.
# Location:Great Britain
# Following Count:377
# Follower Count:1061854
# Total Tweets:700606
# Retweet Count:0
# Tweet Text:🎟️#BarkingRiverside - To assist with your journey, you may use your ticket with the following operators:
# - Greater Anglia
# - c2c
# - Great Northern
# - Thameslink
# - London Underground
# - Elizabeth line
# Hashtags Used:['BarkingRiverside']
# Place:None
# Geoe:False
#
# Tweet 25:
# Username:Se_Railway
# Description:Providing real-time information about Southeastern services 24/7. For comments, complaints, & fares information, please visit our website or call 0345 322 7021
# Location:London, Kent and East Sussex
# Following Count:132
# Follower Count:247003
# Total Tweets:781789
# Retweet Count:0
# Tweet Text:⚠️ONGOING: #Hayes
# ❌No service between Hayes and Elmers End.
# ❌Trains towards London also cannot stop at Lower Sydenham
# 🎫Tickets accepted on the following:
# 🚌London Buses Hayes - Lewisham.
# 🚋Tramlink services Elmers End - East Croydon
# 🚆Thameslink services East Croydon - London
# Hashtags Used:['Hayes']
# Place:None
# Geoe:True
#
# Tweet 26:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update)  06:02 Orpington to Luton due 07:50 - 06:02 Orpington to Luton due 07:50 has been cancelled.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 27:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update)  08:00 Luton to Orpington due 09:46 - 08:00 Luton to Orpington due 09:46 will be cancelled.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 28:
# Username:Se_Railway
# Description:Providing real-time information about Southeastern services 24/7. For comments, complaints, & fares information, please visit our website or call 0345 322 7021
# Location:London, Kent and East Sussex
# Following Count:132
# Follower Count:247003
# Total Tweets:781789
# Retweet Count:0
# Tweet Text:⚠️ONGOING: #Hayes
# ❌No service between Hayes and Elmers End.
# ❌Trains towards London also cannot stop at Lower Sydenham
# 🎫Tickets accepted on the following:
# 🚌London Buses Hayes - Lewisham
# 🚋Tramlink services Elmers End - East Croydon
# 🚆Thameslink services East Croydon - London
# Hashtags Used:['Hayes']
# Place:None
# Geoe:True
#
# Tweet 29:
# Username:bwianair
# Description:General purpose idiot. Fan of horror, forteana, strange noises and other oddities.
# @Brianair@mastodon.online
# Location:Bromley, London
# Following Count:2573
# Follower Count:735
# Total Tweets:43920
# Retweet Count:0
# Tweet Text:@hazel__louise @Se_Railway On a Thameslink train just near Peckham Rye, announcement just made that a passenger alarm was pulled on a train in the station so its all being reset.
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 30:
# Username:nationalrailenq
# Description:24/7 support across the National Rail network. Real time updates and advice on services provided. All DMs deleted after 30 days of conversation ending.
# Location:Great Britain
# Following Count:377
# Follower Count:1061854
# Total Tweets:700606
# Retweet Count:0
# Tweet Text:💳#LowerSydenham - You can use your ticket on the following services at no extra cost:
# 🔹London Buses between Hayes and Lewisham
# 🔹Tramlink services between Elmers End and East Croydon
# 🔹Thameslink service between East Croydon and London
# Hashtags Used:['LowerSydenham']
# Place:None
# Geoe:False
#
# Tweet 31:
# Username:Se_Railway
# Description:Providing real-time information about Southeastern services 24/7. For comments, complaints, & fares information, please visit our website or call 0345 322 7021
# Location:London, Kent and East Sussex
# Following Count:132
# Follower Count:247003
# Total Tweets:781789
# Retweet Count:0
# Tweet Text:⚠️UPDATE: #Hayes
# ❌No service between Hayes and Elmers End. Trains towards London also cannot stop at Lower Sydenham
# 🎫Tickets accepted on the following:
# 🚌London Buses Hayes - Lewisham
# 🚋Tramlink services Elmers End - East Croydon
# 🚆Thameslink services East Croydon - London https://t.co/uXwoeU81fZ
# Hashtags Used:['Hayes']
# Place:None
# Geoe:True
#
# Tweet 32:
# Username:DieselDragonUK
# Description:Metalhead, Hacker, Orienteer, European. @TheBrexitFairy. #LGBT neo-Druid specialising in the arts of power and strength to make our World a better place for all
# Location:United Kingdom
# Following Count:507
# Follower Count:367
# Total Tweets:7806
# Retweet Count:0
# Tweet Text:@NathLei_F1 And still it won't have enough capacity for all of those wanting to cram through the ThamesLink core in the same 30-minute window as everybody else... 🙃
#
# Does anybody think a 60mph conveyor belt might do the trick? #HoldOn 🧍💨😁
# Hashtags Used:['HoldOn']
# Place:None
# Geoe:False
#
# Tweet 33:
# Username:j65_2
# Description:You know, Quasimodo predicted all this.
# Location:
# Following Count:629
# Follower Count:19
# Total Tweets:1765
# Retweet Count:0
# Tweet Text:@hiltonholloway It's a jungle out there on Thameslink.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 34:
# Username:erica_in_london
# Description:📍American Transplant trying to figure out the UK ⚠️ Help me I’m new here
# Location:London, England
# Following Count:35
# Follower Count:1
# Total Tweets:3
# Retweet Count:0
# Tweet Text:@TLRailUK what is the difference between a ticket from SAC &gt; London Thameslink and SAC &gt; London Terminals?
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 35:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update) Ickenham Station Information - Ickenham: No Step Free Access - Step free access is not available due to unavailability of station staff. Call us on 0343 222 1234 if you need help planning your journey.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 36:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update) West Finchley Station Information - West Finchley: No Step Free Access - Step free access between the train and the platform via ramp is not available due to unavailability of station staff. Call 0343 222 1234 if you need help planning your journey.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 37:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update) Mon, 21 November 06:58 Orpington to Luton due 08:50 - 21/11/22 06:58 Orpington to Luton due 08:50 will be cancelled.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 38:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update)  19:49 Sutton Surrey to Luton due 21:38 - 19:49 Sutton Surrey to Luton due 21:38 has been delayed at London Blackfriars and is now 7 minutes late.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 39:
# Username:GaahngedCrypto
# Description:مواظب کفتارای دورت باش  ://
# Location:Heard Island and Mcdonald Islands
# Following Count:10
# Follower Count:0
# Total Tweets:8
# Retweet Count:2
# Tweet Text:📢 Due to the nature of the Thameslink network, although this incident is north of London, it will also affect trains through Central London and south of there.
#
# 🎫 Tickets will be accepted on @Metrobus services between Redhill and Gatwick Airport.
#
# https://t.co/iYMraBkRI6
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 40:
# Username:lokiavivson
# Description:19
# Based in London, United Kingdom
# Rail/Aviation and other random stuff
# He/Him
# Follow/like/RT ≠ endorsement
# Location:London, England
# Following Count:1587
# Follower Count:457
# Total Tweets:14304
# Retweet Count:0
# Tweet Text:@DamiAgunbiade @pranavraval87 @cnbcwatcher90 @TfL They also updated the announcements at Liverpool Street! Also, Thameslink trains are slowly having their announcements updated. Greater Anglia's horrendous Class 720s also have updated announcements at Liverpool Street, Stratford, Romford and Shenfield
# Hashtags Used:[]
# Place:Place(_api=<tweepy.api.API object at 0x000001615AF5A280>, id='21a9d859b598883a', url='https://api.twitter.com/1.1/geo/id/21a9d859b598883a.json', place_type='city', name='Southall', full_name='Southall, London', country_code='GB', country='United Kingdom', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000001615AF5A280>, type='Polygon', coordinates=[[[-0.419679, 51.491499], [-0.302681, 51.491499], [-0.302681, 51.559366], [-0.419679, 51.559366]]]), attributes={})
# Geoe:True
#
# Tweet 41:
# Username:midland__london
# Description:UK based rail traveller & enthusiast. 00 gauge modeller. #TMRGUK. Views my own. When I'm not travelling on trains, you'll find me making videos about them 👇
# Location:Somewhere on the Iron Road...
# Following Count:134
# Follower Count:2053
# Total Tweets:12375
# Retweet Count:0
# Tweet Text:Tell me you’re on board Thameslink without telling me you’re on board Thameslink… 🙃😂 https://t.co/0pFQlvbMPe
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 42:
# Username:JeSuisUnDan
# Description:buenos ding dong diddly dias señor
# Location:In the four foot
# Following Count:1181
# Follower Count:817
# Total Tweets:68602
# Retweet Count:0
# Tweet Text:I've dropped six in the four foot alone at Bricklayers Arms during the Thameslink project. Excellent operator on the RDT that night. https://t.co/gPaitMcfKr
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 43:
# Username:ICTrains125
# Description:Questionable human being, transport, motoring and aviation enthusiast.
# Location:London
# Following Count:437
# Follower Count:177
# Total Tweets:2075
# Retweet Count:0
# Tweet Text:@RedRoseDart Did you see someone in a blue Dublin sweater?
#
# If so, that was me (I’m on a Thameslink train coming back and charging my phone atm)
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 44:
# Username:Abyssreaper99
# Description:23 • He/Him • Probably likes gaming and music too much
# Location:Leicester, England
# Following Count:395
# Follower Count:78
# Total Tweets:2597
# Retweet Count:0
# Tweet Text:Had to have a mad dash from one train platform to another in et Pancreas because my one came in 10 mins late. People nearly tripping me up by stepping on the backs of my shoes didn't help. 30 secs later and I would have missed the Thameslink to Brighton
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 45:
# Username:TrainBeacon
# Description:📱Mobile app. Shows estimated UK train positions in augmented reality and on map
# Location:🚉 🍏App Store & Google Play
# Following Count:5708
# Follower Count:5320
# Total Tweets:369271
# Retweet Count:0
# Tweet Text:Train Beacon detected that Thameslink has 3 cancellations up until the end of the day. https://t.co/gN68PccyB0
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 46:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update)  17:16 Sutton Surrey to St Albans City due 18:36 - 17:16 Sutton Surrey to St Albans City due 18:36 will be cancelled.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 47:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update)  18:52 St Albans City to Sutton Surrey due 20:17 - 18:52 St Albans City to Sutton Surrey due 20:17 will be cancelled.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 48:
# Username:TfL
# Description:We’re here to help you get where you’re going in London 🚶 🚲 🚇 🚌 🚠
# Location:London, England
# Following Count:98
# Follower Count:2486604
# Total Tweets:184487
# Retweet Count:0
# Tweet Text:@LOTTIEJENKINS Hi Charlotte, thanks for your message.
#
# Complaints about staff at Denmark Hill should be taken up with Thameslink that manage the station (including the staff).
#
# ^CO
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 49:
# Username:TLRailUK
# Description:Hello from Thameslink 👋! Taking you across London and beyond; we're here to help 24 hours a day, 7 days a week.
# Location:UK
# Following Count:263
# Follower Count:91806
# Total Tweets:341953
# Retweet Count:0
# Tweet Text:@LOTTIEJENKINS @TfL Hi Charlotte. London Overground trains do stop at this station, but the stations itself is managed by Thameslink. If there's anything I can do to help, please let me know. You can use the link below to send me a direct message if you like.  ^Stu https://t.co/yTQR8FkoDd
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 50:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update)  15:22 Luton to Sutton Surrey due 17:14 - 15:22 Luton to Sutton Surrey due 17:14 has been cancelled.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 51:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update)  20:19 Sutton Surrey to Luton due 22:08 - 20:19 Sutton Surrey to Luton due 22:08 will be cancelled.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 52:
# Username:TfL
# Description:We’re here to help you get where you’re going in London 🚶 🚲 🚇 🚌 🚠
# Location:London, England
# Following Count:98
# Follower Count:2486604
# Total Tweets:184487
# Retweet Count:0
# Tweet Text:@LOTTIEJENKINS Hi Charlotte, thanks for your message.
#
# Denmark Hill station is owned and managed by Thameslink ( @TLRailUK ), not TfL.
# It's best to contact them directly with details of your son's experience.
# You may find this link to their contact page useful: https://t.co/rxXUM9dtLz
#
# ^CO
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 53:
# Username:SouthernRailUK
# Description:Hi from the Southern Social team 👋! Taking you across the South Coast, London and more; we're here to help 24 hours a day, 7 days a week.
# Location:UK
# Following Count:1787
# Follower Count:194474
# Total Tweets:774488
# Retweet Count:0
# Tweet Text:@DanRJohnson Hi Dan. If you're traveling from Gatwick Airport to Wimbledon, I'd advise taking a train to London Bridge, and changing there for Thameslink services to Wimbledon. This is due to planned engineering work is taking place between East Croydon and Victoria this weekend. ^Stu
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 54:
# Username:johnofladublin
# Description:Irish accountant interested in world affairs, weather, travel, transport & watching Ireland beat England, France & now NZ in rugby! All views are mine alone.
# Location:Dublin
# Following Count:1546
# Follower Count:363
# Total Tweets:20278
# Retweet Count:0
# Tweet Text:Taking a spin around the Wimbledon loop on a Thameslink train - some of London’s quietest stations includes one that isn’t in the Channel Islands! https://t.co/CFG2gzTotE
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 55:
# Username:TLRailUK
# Description:Hello from Thameslink 👋! Taking you across London and beyond; we're here to help 24 hours a day, 7 days a week.
# Location:UK
# Following Count:263
# Follower Count:91806
# Total Tweets:341953
# Retweet Count:0
# Tweet Text:@tcordrey Hi Tanya. No Gatwick  Express trains are running today, and no trains will run to or from London Victoria. This is due to engineering work taking place today.
#
# Southern Rail and Thameslink services will run between Gatwick and London Bridge to connect to London services. ^Stu
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 56:
# Username:MichaelCHilton
# Description:Rabbi, Teacher, Author, Campaigner, Friend
# Location:London UK
# Following Count:706
# Follower Count:441
# Total Tweets:5332
# Retweet Count:0
# Tweet Text:@TLRailUK The train left West Hampstead Thameslink at 10:18 this morning from Platform 2 advertised as all stations to Luton. It went direct to St Albans headed for Bedford. Please could you make sure this is reported as it is not acceptable to take passengers to the wrong place.
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 57:
# Username:mjp_hall1980
# Description:Pensions actuary. All kinds of theatre in spare time. Empire Done in 60 Seconds competition finalist 6x. Current CODA Chairman.
# Location:South Croydon.  The nice bit.
# Following Count:1092
# Follower Count:321
# Total Tweets:8733
# Retweet Count:0
# Tweet Text:@catherinerusse2 Followed you ever since your many complaints about Thameslink. Thank you for so many great comments and pictures, and well done in Habeas Corpus.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 58:
# Username:MichaelCHilton
# Description:Rabbi, Teacher, Author, Campaigner, Friend
# Location:London UK
# Following Count:706
# Follower Count:441
# Total Tweets:5332
# Retweet Count:0
# Tweet Text:@TLRailUK Quite a few passengers frustrated and late after being whisked direct to St Albans after incorrect departure information at West Hampstead Thameslink. Not a happy bunch!
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 59:
# Username:dhlfastestlap
# Description:extremely biased towards Sir Lewis Hamilton.
# Location:she/her | LH44 | I’m black btw
# Following Count:907
# Follower Count:1411
# Total Tweets:23358
# Retweet Count:0
# Tweet Text:Which train company is the worst and why is it Thameslink??
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 60:
# Username:departmentals
# Description:https://t.co/ce4cnZUY1v - departmental stock and internal user vehicles on UK railways. https://t.co/BxflC7jNqQ editor, https://t.co/ZfDKvl4jlf contributor
# Location:Oxfordshire, United Kingdom
# Following Count:207
# Follower Count:254
# Total Tweets:1785
# Retweet Count:0
# Tweet Text:62287 (Ultrasonic Test Train coach - UTU2) at West Hampstead Thameslink - 7 November 2022.
# Photo (c) Robin Morel. #departmentals #railway #internaluser
# https://t.co/nNoYxbpviV
# Hashtags Used:['departmentals', 'railway', 'internaluser']
# Place:None
# Geoe:True
#
# Tweet 61:
# Username:_aleem
# Description:# git status https://t.co/nbvNpmXbIQ Visited 🇧🇻🇵🇰🇸🇦🇩🇰🇭🇺🇺🇿🇸🇪  Hobbies  🏊‍♂️⛹️‍♂️🤾‍♂️⚽
# Location:Oslo, Norway
# Following Count:838
# Follower Count:45
# Total Tweets:131
# Retweet Count:0
# Tweet Text:Coffee , vacations and evening. What a good evening.
# #worklifebalance #ericsson #ericssonawesome #teamericsson  #coffee #evening #holiday #vacation #uk #sweden #norway #pakistan #emr #thameslink #gatwickairport #london https://t.co/vR4imeFFlZ
# Hashtags Used:['worklifebalance', 'ericsson', 'ericssonawesome', 'teamericsson', 'coffee', 'evening', 'holiday', 'vacation', 'uk', 'sweden', 'norway', 'pakistan', 'emr', 'thameslink', 'gatwickairport', 'london']
# Place:Place(_api=<tweepy.api.API object at 0x000001615AF5A280>, id='07d9ec7370085000', url='https://api.twitter.com/1.1/geo/id/07d9ec7370085000.json', place_type='poi', name='Peterborough Railway Station (PBO)', full_name='Peterborough Railway Station (PBO)', country_code='GB', country='United Kingdom', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000001615AF5A280>, type='Polygon', coordinates=[[[-0.2498235335471614, 52.57453381509294], [-0.2498235335471614, 52.57453381509294], [-0.2498235335471614, 52.57453381509294], [-0.2498235335471614, 52.57453381509294]]]), attributes={})
# Geoe:True
#
# Tweet 62:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update) Fulham Broadway Station Information - Fulham Broadway: No Step Free Access - Step free access is not available to the westbound platform due to a faulty lift. Call us on 0343 222 1234 if you need help planning your journey.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 63:
# Username:kelvin5385
# Description:Erm, I'm me and I am an engineer, keeping trains moving in SE England. Classic car and bus enthusiast and owner - don't ask.
# Location:Kent
# Following Count:298
# Follower Count:176
# Total Tweets:12085
# Retweet Count:0
# Tweet Text:@pacer142 @SELondoner1 @SteveWhiteRail Probably  can't find it now, but there was a long thread by NWR explaining the complexities of level boarding. Thameslink have level boarding at LB, for disabled access only but think these platforms are restricted to 700s.
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 64:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update) Cockfosters Station Information - Cockfosters: No Step Free Access - Step free access is not available due to unavailability of station staff. Call us on 0343 222 1234 if you need help planning your journey.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 65:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update) West Finchley Station Information - West Finchley: No Step Free Access - Step free access between the train and the platform via ramp is not available due to unavailability of station staff. Call 0343 222 1234 if you need help planning your journey.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 66:
# Username:DispatcherBML
# Description:Railwayman - Dispatcher on the Brighton Main Line. No tweets/photos during safety critical duties & my views are all my own. Bulleid (Light) Pacific enthusiast.
# Location:Not on a night shift
# Following Count:465
# Follower Count:310
# Total Tweets:1739
# Retweet Count:0
# Tweet Text:8 till 4 today, the closest I ever get to a ‘normal’ shift, except it always falls on a Sunday. Not the day for an atmospheric photo from the viaduct, unless you love Thameslink interiors. 😂 https://t.co/DpJa2OCMga
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 67:
# Username:Volvoman90
# Description:BSc. Pharmacology. Designs stuff. Photographs stuff. Cancer beater. The Earth is not flat. We went to the moon. NASA Payroll #5318008.
# Location:🇬🇧
# Following Count:1631
# Follower Count:870
# Total Tweets:20222
# Retweet Count:0
# Tweet Text:@SylviaMaryRyan3 Broadway. Well nearly Mitcham 🤣
# Next to Tooting Thameslink station 👍
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 68:
# Username:48HrsOnTheTube
# Description:48 hours on the London Underground? Completed it mate. Ali | Tube Nerd | Doer of silly things.
# Location:
# Following Count:247
# Follower Count:772
# Total Tweets:250
# Retweet Count:0
# Tweet Text:@aiyeethesquid Missed this Q! Really tricking one, because I think Lizzy line and overground should obviously be on there, and Thameslink too probably, but then no sure where that stops!
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 69:
# Username:cnbcwatcher90
# Description:Law grad|Britney Spears fan 👱‍♀️|Sonic fan🦔| London Underground enthusiast🚇|Gamer🎮|Computer nerd🖥|pop music fan🎤💃|Pokemon + Potter fan|Student notetaker
# Location:Underground, overground
# Following Count:4997
# Follower Count:2140
# Total Tweets:156329
# Retweet Count:1
# Tweet Text:@geofftech @48HrsOnTheTube The Jubilee Line has a secret junction which connects to the Thameslink Core tunnels. Initially, the plan was to have 4 carriage Thameslink Class 700s run a limited 2 tph service from London Bridge to West Hampstead.
#
# #MadeUpTubeFacts @48HrsOnTheTube
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 70:
# Username:digassets4
# Description:I'm Esther a graduate of the University of Greenwich.  I specialise in the selling of products (digital and physical), blogging and affiliate marketing
# Location:London, United Kingdom
# Following Count:316
# Follower Count:359
# Total Tweets:12439
# Retweet Count:4
# Tweet Text:⚠️ A phone system problem is causing disruption to trains controlled by one of the signalling centres at Three Bridges.
#
# A number of Southern, Thameslink and Gatwick Express trains are likely to be delayed this afternoon.
#
# ℹ️ Service information to follow.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 71:
# Username:TrainBeacon
# Description:📱Mobile app. Shows estimated UK train positions in augmented reality and on map
# Location:🚉 🍏App Store & Google Play
# Following Count:5708
# Follower Count:5320
# Total Tweets:369271
# Retweet Count:0
# Tweet Text:Train Beacon detected that Thameslink has 1.11% of timetabled services cancelled up until the end of the day. https://t.co/gN68PccyB0
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 72:
# Username:nlygo
# Description:faggot 🏳️‍🌈, Jew, cancer survivor, incontinent; tweet on politics, meejah, #HIV & general health, #PrEP U=U & more. #AIDS widow. #COYS! nlygo@aol.com
# Location:London/ Edgware
# Following Count:357
# Follower Count:1802
# Total Tweets:334661
# Retweet Count:0
# Tweet Text:@Simonablake take the train from London Bridge (Thameslink) to Brighton. It's slower, but cheaper.
#
# Return from £13.70 tomorrow.
#
# https://t.co/fWNnWfRSB1
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 73:
# Username:wobblysteve65
# Description:Non PC, acerbic, grumpy so-and-so with feck all of any interest to say.
# Location:
# Following Count:410
# Follower Count:122
# Total Tweets:6163
# Retweet Count:0
# Tweet Text:@geofftech Corby will be the most northerly Thameslink station #NorthLondonshire #MadeUpRailFacts
# Hashtags Used:['NorthLondonshire', 'MadeUpRailFacts']
# Place:None
# Geoe:False
#
# Tweet 74:
# Username:anzastasiea
# Description:Keep calm
# Location:Hong Kong
# Following Count:5
# Follower Count:0
# Total Tweets:2
# Retweet Count:3
# Tweet Text:Our vaccine bus now offers flu vaccinations as well as COVID-19 1st, 2nd &amp; boosters (Pfizer) + boosters (Pfizer bivalent)
#
# Drop by, 11am-4pm:
#
# 🔷19 Nov - 29-39 Brunswick Sq
# 🔷24-26 Nov - Swiss Cottage Market
# 🔷1-3 Dec - West Hampstead Thameslink
#
# Info at https://t.co/W29CTYxH0h https://t.co/9QTUXiCN03
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 75:
# Username:Se_Railway
# Description:Providing real-time information about Southeastern services 24/7. For comments, complaints, & fares information, please visit our website or call 0345 322 7021
# Location:London, Kent and East Sussex
# Following Count:132
# Follower Count:247003
# Total Tweets:781789
# Retweet Count:0
# Tweet Text:@Nicolamartin198 No, Thameslink are not affected either ^PK
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 76:
# Username:Nicolamartin198
# Description:
# Location:Dartford, South East
# Following Count:722
# Follower Count:108
# Total Tweets:5011
# Retweet Count:0
# Tweet Text:@Se_Railway @Se_Railway is the Thameslink service from Dartford affected on that day, or will that be okay?
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 77:
# Username:Naddy37
# Description:🌈🦄ShE/HeR wHoSe NoT yEt fUlLy oUt, OuT! 🚂TrAiN & aViAtIoN NeRd✈, Ex-NhS🐉D&d NoOb🗝💦dEtAiLiNG & vALeTiNg GeEk💦 #roadsafety #mentalhealth #OCD #NHS 🦄🌈
# Location:Planet Earth
# Following Count:1325
# Follower Count:723
# Total Tweets:30101
# Retweet Count:0
# Tweet Text:@PouncerSD That’s the exact reason why when attending my Charing Cross hospital appointments, I always sat in 1st class. Luckily, Thameslink declassify the rear most 1st class compartment. Many don’t know that, hence peace n quiet x
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 78:
# Username:davwheat_
# Description:18. Core developer at @Flarum. Studying Computer Science. Mobile networking is my hobby. Also kinda like trains, sometimes.
#
# All views are my own.
# Location:West Sussex, United Kingdom
# Following Count:497
# Follower Count:283
# Total Tweets:1311
# Retweet Count:1
# Tweet Text:@geofftech @48HrsOnTheTube The Jubilee Line has a secret junction which connects to the Thameslink Core tunnels. Initially, the plan was to have 4 carriage Thameslink Class 700s run a limited 2 tph service from London Bridge to West Hampstead.
#
# #MadeUpTubeFacts @48HrsOnTheTube
# Hashtags Used:['MadeUpTubeFacts']
# Place:None
# Geoe:True
#
# Tweet 79:
# Username:yareihtza
# Description:WTF is an NFT?
# Location:Virgin Islands, British
# Following Count:5
# Follower Count:1
# Total Tweets:2
# Retweet Count:1
# Tweet Text:⚠️UPDATE: #StPancras
#
# The train for the 00:12 will run from St Pancras to Gravesend and then back. Passengers can then pick up a Thameslink service to Gillingham and then a Southeastern service has been extended to Faversham.
#
# The 00:12 should run but will be delayed.
# Hashtags Used:['StPancras']
# Place:None
# Geoe:False
#
# Tweet 80:
# Username:JacuobsS
# Description:I ❤️ NFTs.
# Location:Colombia
# Following Count:5
# Follower Count:0
# Total Tweets:2
# Retweet Count:1
# Tweet Text:🎫 You can use your ticket to complete your journey on:
#
# 👉 Southern or Thameslink trains on any reasonable route.
#
# 👉 London Underground between Wimbledon and Morden
#
# 👉 London Buses between Wimbledon and Sutton
#
# 🗺 To see if your journey is affected 👇
#
# https://t.co/Q6JYQFhmyf
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 81:
# Username:TrainBeacon
# Description:📱Mobile app. Shows estimated UK train positions in augmented reality and on map
# Location:🚉 🍏App Store & Google Play
# Following Count:5708
# Follower Count:5320
# Total Tweets:369271
# Retweet Count:0
# Tweet Text:Train Beacon detected that Thameslink has 3 cancellations up until the end of the day. https://t.co/gN68PcuHP8
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 82:
# Username:w4stedtalent
# Description:personal diary
# Location:Wasteland
# Following Count:667
# Follower Count:86
# Total Tweets:17912
# Retweet Count:0
# Tweet Text:A ticket inspector on this thameslink and I hearing this correctly??
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 83:
# Username:JohnRaf38663945
# Description:Grey haired. Old rocker
# Location:
# Following Count:667
# Follower Count:109
# Total Tweets:2556
# Retweet Count:0
# Tweet Text:Thameslink Class 700 Arrives at Dartford With a Service to Luton this afternoon.taking this as far as Greenwich https://t.co/9urseIJKyX
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 84:
# Username:TrainBeacon
# Description:📱Mobile app. Shows estimated UK train positions in augmented reality and on map
# Location:🚉 🍏App Store & Google Play
# Following Count:5708
# Follower Count:5320
# Total Tweets:369271
# Retweet Count:0
# Tweet Text:Train Beacon detected that Thameslink has 1.1% of timetabled services cancelled up until the end of the day. https://t.co/gN68Pcu9ZA
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 85:
# Username:MatHempell
# Description:ladder karen
# Location:🪜
# Following Count:1004
# Follower Count:1712
# Total Tweets:68918
# Retweet Count:0
# Tweet Text:We are on the first class carriage on Thameslink that you can use with a normal ticket! https://t.co/VMNoqgdhbf
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 86:
# Username:RichFM39517086
# Description:WDON RADIO ~ # ROCK # BLUES # POP $ LEGENDARY MONEY!!
# Location:Laguna Beach, Ca
# Following Count:4986
# Follower Count:2856
# Total Tweets:887721
# Retweet Count:1
# Tweet Text:💳#HerneHill - Thameslink customers may use their ticket on the following services at no extra cost:
#
# ▪️London Buses between Streatham and London Blackfriars
# ▪️London Underground between Wimbledon and London
# Hashtags Used:['HerneHill']
# Place:None
# Geoe:True
#
# Tweet 87:
# Username:NathLei_F1
# Description:ALL views are mine and not those of any company I am employed by. Train dispatcher in Gatwick, Sussex, living the dream :)
# Location:A train station
# Following Count:2152
# Follower Count:1363
# Total Tweets:43782
# Retweet Count:0
# Tweet Text:Horsham is doing a very un-Horsham thing today. Thameslink in 1 is something I have never ever seen. https://t.co/pw2DwSpguq
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 88:
# Username:sexycorn69
# Description:he/xe. no worries if not. #teamjonbers
# Location:big gay brighton
# Following Count:710
# Follower Count:787
# Total Tweets:46342
# Retweet Count:0
# Tweet Text:Damn this thameslink rly is causing me psychic damage
# Hashtags Used:[]
# Place:Place(_api=<tweepy.api.API object at 0x000001615AF5A280>, id='086f3fef1238538b', url='https://api.twitter.com/1.1/geo/id/086f3fef1238538b.json', place_type='city', name='Haywards Heath', full_name='Haywards Heath, England', country_code='GB', country='United Kingdom', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000001615AF5A280>, type='Polygon', coordinates=[[[-0.12149, 50.979306], [-0.07077, 50.979306], [-0.07077, 51.016568], [-0.12149, 51.016568]]]), attributes={})
# Geoe:True
#
# Tweet 89:
# Username:TrainBeacon
# Description:📱Mobile app. Shows estimated UK train positions in augmented reality and on map
# Location:🚉 🍏App Store & Google Play
# Following Count:5708
# Follower Count:5320
# Total Tweets:369271
# Retweet Count:0
# Tweet Text:🌉 Thameslink update: Due to a road vehicle colliding with a bridge between Tulse Hill and Herne Hill the line towards London Blackfriars is closed. https://t.co/gN68Pcu9ZA 🌉
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 90:
# Username:TLRailUK
# Description:Hello from Thameslink 👋! Taking you across London and beyond; we're here to help 24 hours a day, 7 days a week.
# Location:UK
# Following Count:263
# Follower Count:91806
# Total Tweets:341953
# Retweet Count:0
# Tweet Text:@JazzyMcD Hi there. Apologies for the delay in replying. Our Thameslink trains do not have staff on board. I can get this reported now so our staff are aware, and you should be able to purchase your ticket at your destination if you speak to our gate line staff. ^Stu
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 91:
# Username:sexycorn69
# Description:he/xe. no worries if not. #teamjonbers
# Location:big gay brighton
# Following Count:710
# Follower Count:787
# Total Tweets:46342
# Retweet Count:0
# Tweet Text:When u wanna read Ur book on the train but u also bought a coffee &amp; ur on the Thameslink trains with no tables 😍🙌
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 92:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update)  11:16 Sutton Surrey to St Albans City due 12:37 - 11:16 Sutton Surrey to St Albans City due 12:37 was started from Wimbledon.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 93:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update)  11:37 St Albans City to Sutton Surrey due 13:14 - 11:37 St Albans City to Sutton Surrey due 13:14 will be terminated at Wimbledon.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 94:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update)  12:07 St Albans City to Sutton Surrey due 13:44 - 12:07 St Albans City to Sutton Surrey due 13:44 will be terminated at Wimbledon.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 95:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update)  12:16 Sutton Surrey to St Albans City due 13:37 - 12:16 Sutton Surrey to St Albans City due 13:37 will be started from Wimbledon.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 96:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update)  12:46 Sutton Surrey to St Albans City due 14:07 - 12:46 Sutton Surrey to St Albans City due 14:07 will be started from Wimbledon.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 97:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update)  13:16 Sutton Surrey to St Albans City due 14:37 - 13:16 Sutton Surrey to St Albans City due 14:37 will be started from Wimbledon.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 98:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update)  13:46 Sutton Surrey to St Albans City due 15:07 - 13:46 Sutton Surrey to St Albans City due 15:07 will be started from Wimbledon.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 99:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update)  12:19 Sutton Surrey to St Albans City due 13:52 - 12:19 Sutton Surrey to St Albans City due 13:52 will be diverted from Sutton Surrey.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 100:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# ...
# Hashtags Used:[]
# Place:Place(_api=<tweepy.api.API object at 0x000001615AF5A280>, id='1da00c8852cc9da2', url='https://api.twitter.com/1.1/geo/id/1da00c8852cc9da2.json', place_type='city', name='Newport', full_name='Newport, Wales', country_code='GB', country='United Kingdom', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000001615AF5A280>, type='Polygon', coordinates=[[[-3.0812071, 51.549936], [-2.970463, 51.549936], [-2.970463, 51.621386], [-3.0812071, 51.621386]]]), attributes={})
# Geoe:True
#
# Tweet 585:
# Username:SouthernRailUK
# Description:Hi from the Southern Social team 👋! Taking you across the South Coast, London and more; we're here to help 24 hours a day, 7 days a week.
# Location:UK
# Following Count:1787
# Follower Count:194474
# Total Tweets:774488
# Retweet Count:1
# Tweet Text:Thameslink trains to Sutton / West Hampstead Thameslink are still running as advertised.
#
# 🎫 If you are looking for an alternative route, tickets are being accepted on London Buses through the affected area.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 586:
# Username:uncriticalsimon
# Description:Not a bot. Not 🏴󠁧󠁢󠁷󠁬󠁳󠁿 but live in Wales. Most disappointing maths PhD grad 🏆. "Uncritical" = not essential. ?SYNTAX ERROR. READY.
# Location:Newport
# Following Count:4999
# Follower Count:2966
# Total Tweets:228887
# Retweet Count:0
# Tweet Text:https://t.co/0M4z9Oe2Cw
#
# OK so why can't I get a ticket from Newport (or even Cwmbran or Cardiff) to London Thameslink, or specifically to Farringdon (other than a normal London Terminals ticket and a Tube ticket), changing at Salisbury and Clapham Junction?
# Hashtags Used:[]
# Place:Place(_api=<tweepy.api.API object at 0x000001615AF5A280>, id='1da00c8852cc9da2', url='https://api.twitter.com/1.1/geo/id/1da00c8852cc9da2.json', place_type='city', name='Newport', full_name='Newport, Wales', country_code='GB', country='United Kingdom', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000001615AF5A280>, type='Polygon', coordinates=[[[-3.0812071, 51.549936], [-2.970463, 51.549936], [-2.970463, 51.621386], [-3.0812071, 51.621386]]]), attributes={})
# Geoe:True
#
# Tweet 587:
# Username:uncriticalsimon
# Description:Not a bot. Not 🏴󠁧󠁢󠁷󠁬󠁳󠁿 but live in Wales. Most disappointing maths PhD grad 🏆. "Uncritical" = not essential. ?SYNTAX ERROR. READY.
# Location:Newport
# Following Count:4999
# Follower Count:2966
# Total Tweets:228887
# Retweet Count:0
# Tweet Text:One weird thing about the London public transport system is that the Underground is *not* well integrated with buses (or trams) but *is* well integrated with mainline rail (including Overground and Elizabeth line), e.g. Cannon Street to City Thameslink is just a Tube fare.
# Hashtags Used:[]
# Place:Place(_api=<tweepy.api.API object at 0x000001615AF5A280>, id='1da00c8852cc9da2', url='https://api.twitter.com/1.1/geo/id/1da00c8852cc9da2.json', place_type='city', name='Newport', full_name='Newport, Wales', country_code='GB', country='United Kingdom', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000001615AF5A280>, type='Polygon', coordinates=[[[-3.0812071, 51.549936], [-2.970463, 51.549936], [-2.970463, 51.621386], [-3.0812071, 51.621386]]]), attributes={})
# Geoe:True
#
# Tweet 588:
# Username:TLRailUK
# Description:Hello from Thameslink 👋! Taking you across London and beyond; we're here to help 24 hours a day, 7 days a week.
# Location:UK
# Following Count:263
# Follower Count:91806
# Total Tweets:341953
# Retweet Count:0
# Tweet Text:👷‍♀️👷‍♂️ Network Rail are carrying out improvement works this weekend between West Hampstead Thameslink and Luton.
#
# There will be no trains between these stations today &amp; Sunday 13 November. Replacement buses will be running.
#
# 🚉 Check ahead at https://t.co/nc6tyEmgTu https://t.co/ocRZnGUyMh
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 589:
# Username:ArtDecoWalkabt
# Description:Raver/Junglist/Art Deco Enthusiast, meow game. 60s/70s/80s kitch
# Location:
# Following Count:658
# Follower Count:274
# Total Tweets:32119
# Retweet Count:1
# Tweet Text:Massive incident on my #Thameslink train 9W12 08:29 ex-Brighton. 😬 Got to Three Bridges and driver announces a "medical incident on the train" but more police than ambulance here. 🤨 Been here 30mins now being evacuated from the station. 👇 @TLRailUK @NetworkRailSE @BTPSussex https://t.co/3Mu8kEkHhM
# Hashtags Used:['Thameslink']
# Place:None
# Geoe:True
#
# Tweet 590:
# Username:AvGeek4All
# Description:Dedicated travel profile of @DeltCharlie80 🇿🇦🇬🇧
# Location:London, England
# Following Count:347
# Follower Count:262
# Total Tweets:2271
# Retweet Count:0
# Tweet Text:@jamiebsmith Same, except @Citymapper need to improve the integration into their app suggestion. The EL change at Farringdon to Thameslink is super convenient but not an option
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 591:
# Username:worldofthom
# Description:Actor. Now:https://t.co/VxrAOJVWWt, #DoctorWhoRedacted, @realclintonb’s Karen & other victims, Joan in Clare in the Community @jewellwrightltd @harveyvoices
# Location:London & West Mids
# Following Count:1630
# Follower Count:751
# Total Tweets:1880
# Retweet Count:0
# Tweet Text:@nationalrailenq Ok it’s all becoming surreal now… the ticket office d said they could only release the ticket if it was Thameslink - so I think it’s across a lot of companies … is anyone in charge of this? Did you see reply from @thetrainline ? Thanks!
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 592:
# Username:SussexLive
# Description:The latest news and the best of Sussex across Brighton, Crawley, Hastings, Eastbourne, Worthing, Bognor Regis, Lewes, Chichester. Email: news@sussexlive.co.uk
# Location:Sussex
# Following Count:417
# Follower Count:2989
# Total Tweets:17365
# Retweet Count:0
# Tweet Text:For the latest updates on delays, cancellations and what has happened, follow our blog here
#
# https://t.co/rYFrzNVdCt
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 593:
# Username:TrainBeacon
# Description:📱Mobile app. Shows estimated UK train positions in augmented reality and on map
# Location:🚉 🍏App Store & Google Play
# Following Count:5708
# Follower Count:5320
# Total Tweets:369271
# Retweet Count:0
# Tweet Text:Service Indicator Update: Thameslink is reporting Minor delays on some routes https://t.co/gN68PccyB0
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 594:
# Username:AcmeDR
# Description:EM Consultant. Amateur educator. Quality Improvement. Leadership. Ultrasound. Labradors. National Health Servant. Hate Calibri. #MUFC #NHS #FOAMed
# Location:England, United Kingdom
# Following Count:1469
# Follower Count:3955
# Total Tweets:12868
# Retweet Count:0
# Tweet Text:Ooh ooh now do Thameslink https://t.co/5pLa6zocbz
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 595:
# Username:cathryn_s
# Description:Yorkshire girl born and bred, now living in Wimbledon.
# Location:Wimbledon
# Following Count:143
# Follower Count:35
# Total Tweets:228
# Retweet Count:0
# Tweet Text:@LNER my Thameslink train from Haydons Road is delayed and im@going to@miss my 11.03 train - can I get on a later one?
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 596:
# Username:nationalrailenq
# Description:24/7 support across the National Rail network. Real time updates and advice on services provided. All DMs deleted after 30 days of conversation ending.
# Location:Great Britain
# Following Count:377
# Follower Count:1061854
# Total Tweets:700606
# Retweet Count:0
# Tweet Text:@georgeaLfc We can only apologise on behalf of Southern and Thameslink who operate services on this route. Please continue to follow updates here: https://t.co/WqtaQTon4E
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 597:
# Username:CoolSussex
# Description:One-Stop source of retweets about Sunny Sussex, UK. We auto-retweet the people we follow - just include the word Sussex in the tweet. Enjoy!
# Location:Brighton & Hove, UK
# Following Count:813
# Follower Count:7091
# Total Tweets:522839
# Retweet Count:2
# Tweet Text:🎫 When services resume, your ticket will be permitted for use on alternative Southern, Thameslink and Gatwick Express services to/from London.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 598:
# Username:TLRailUK
# Description:Hello from Thameslink 👋! Taking you across London and beyond; we're here to help 24 hours a day, 7 days a week.
# Location:UK
# Following Count:263
# Follower Count:91806
# Total Tweets:341953
# Retweet Count:0
# Tweet Text:🎫 When services resume, your ticket will be permitted for use on alternative Southern, Thameslink and Gatwick Express services to/from London.
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 599:
# Username:SouthernRailUK
# Description:Hi from the Southern Social team 👋! Taking you across the South Coast, London and more; we're here to help 24 hours a day, 7 days a week.
# Location:UK
# Following Count:1787
# Follower Count:194474
# Total Tweets:774488
# Retweet Count:2
# Tweet Text:🎫 When services resume, your ticket will be permitted for use on alternative Southern, Thameslink and Gatwick Express services to/from London.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 600:
# Username:cmpd_date
# Description:Visit my Flickr for latest photos. 👇📸
# Location:Plumpton, East Sussex
# Following Count:0
# Follower Count:394
# Total Tweets:40
# Retweet Count:1
# Tweet Text:Massive incident on my #Thameslink train 9W12 08:29 ex-Brighton. 😬 Got to Three Bridges and driver announces a "medical incident on the train" but more police than ambulance here. 🤨 Been here 30mins now being evacuated from the station. 👇 @TLRailUK @NetworkRailSE @BTPSussex https://t.co/3Mu8kEkHhM
# Hashtags Used:['Thameslink']
# Place:None
# Geoe:False
#
# Tweet 601:
# Username:GatwickExpress
# Description:Welcome to Gatwick Express! Helping connect you to London and the rest of the world. Our Social team is here 24 hours a day, 7 days a week 🚆✈️🌎.
# Location:London Victoria
# Following Count:732
# Follower Count:66128
# Total Tweets:61592
# Retweet Count:0
# Tweet Text:@fjdfgsdhljkffj1 I'm afraid this fare is only valid via City Thameslink, so it will not be valid on Gatwick Express services. ^Alex
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 602:
# Username:JodyObscure
# Description:Mum of 2💖 fledglings; wife since forever; brain addled & body worn by menopause & life. Longs to laugh at it more & be in my best place. Helped by M&S Gold tea
# Location:East, England
# Following Count:33
# Follower Count:2
# Total Tweets:137
# Retweet Count:0
# Tweet Text:@daraobriain #beautiful Bit different on Thameslink/Southern, you get to see the aggregate heaps at Three Bridges, Croydon skyline and tunnels...the thrill of an overhead low plane at Gatwick or even the beauty of Balcombe viaduct doesn't quite hold the same majesty. Norway #onmylist
# Hashtags Used:['beautiful', 'onmylist']
# Place:None
# Geoe:False
#
# Tweet 603:
# Username:NasaObiallor2
# Description:
# Location:
# Following Count:364
# Follower Count:17
# Total Tweets:11463
# Retweet Count:1
# Tweet Text:👷‍♀️👷‍♂️ Network Rail are carrying out improvement works this weekend between West Hampstead Thameslink and Luton.
#
# There will be no trains between these stations today &amp; Sunday 13 November. Replacement buses will be running.
#
# 🚉 Check ahead at https://t.co/nc6tyE4FuU https://t.co/qxcw2NRe8P
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 604:
# Username:NasaObiallor2
# Description:
# Location:
# Following Count:364
# Follower Count:17
# Total Tweets:11463
# Retweet Count:3
# Tweet Text:👷‍♀️👷‍♂️ Network Rail are carrying out improvement works this weekend between West Hampstead Thameslink and Luton.
#
# There will be no trains between these stations today &amp; Sunday 13 November. Replacement buses will be running.
#
# 🚉 Check ahead at https://t.co/nc6tyEmOJ2 https://t.co/IJFPAVcRYa
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 605:
# Username:NasaObiallor2
# Description:
# Location:
# Following Count:364
# Follower Count:17
# Total Tweets:11463
# Retweet Count:2
# Tweet Text:📢 Due to availability of rail replacement vehicles, a limited bus service will be running on the following routes this weekend:
#
# 👉 Between Luton and Harpenden
# 👉 Between West Hampstead Thameslink and Harpenden
#
# ℹ️ More to follow.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 606:
# Username:TaylesGray
# Description:Youtuber
#
# https://t.co/ThSyA4dXiF
# Location:
# Following Count:196
# Follower Count:11
# Total Tweets:265
# Retweet Count:3
# Tweet Text:👷‍♀️👷‍♂️ Network Rail are carrying out improvement works this weekend between West Hampstead Thameslink and Luton.
#
# There will be no trains between these stations today &amp; Sunday 13 November. Replacement buses will be running.
#
# 🚉 Check ahead at https://t.co/nc6tyEmOJ2 https://t.co/IJFPAVcRYa
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 607:
# Username:CoyModemKnight
# Description:
# Location:
# Following Count:46
# Follower Count:241
# Total Tweets:30165
# Retweet Count:0
# Tweet Text:@Nishtelrooy Thameslink knew at 2325 that your train would be starting from Blackfriars so the only reason for late notice advice is the usual incompetence. It didn't *have to* start there; TLink decided it should, to make up time. Doing this late at night is an utter disgrace.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 608:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update) Victoria Station Information - Victoria: No Step Free Access - Step free access is not available between the National Rail station and the westbound District and Circle line platform. For step free access to all other Underground platforms, use the entran…
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 609:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update) West Finchley Station Information - West Finchley: No Step Free Access - Step free access between the train and the platform via ramp is not available due to unavailability of station staff. Call 0343 222 1234 if you need help planning your journey.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 610:
# Username:TLRailUK
# Description:Hello from Thameslink 👋! Taking you across London and beyond; we're here to help 24 hours a day, 7 days a week.
# Location:UK
# Following Count:263
# Follower Count:91806
# Total Tweets:341953
# Retweet Count:3
# Tweet Text:👷‍♀️👷‍♂️ Network Rail are carrying out improvement works this weekend between West Hampstead Thameslink and Luton.
#
# There will be no trains between these stations today &amp; Sunday 13 November. Replacement buses will be running.
#
# 🚉 Check ahead at https://t.co/nc6tyEmOJ2 https://t.co/IJFPAVcRYa
# Hashtags Used:[]
# Place:None
# Geoe:True
#
# Tweet 611:
# Username:eutc_alerts
# Description:The latest alerts for the @eutc_education community
# Location:London, England
# Following Count:2
# Follower Count:70
# Total Tweets:23268
# Retweet Count:0
# Tweet Text:(Thameslink Update) Wimbledon Park Station Information - Wimbledon Park: No Step Free Access - Step free access is not available due to unavailability of station staff. Call 0343 222 1234 if you need help planning your journey.
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 612:
# Username:TrainBeacon
# Description:📱Mobile app. Shows estimated UK train positions in augmented reality and on map
# Location:🚉 🍏App Store & Google Play
# Following Count:5708
# Follower Count:5320
# Total Tweets:369271
# Retweet Count:0
# Tweet Text:Service Indicator Update: Thameslink is reporting Reduced rail replacement services https://t.co/gN68Pcu9ZA
# Hashtags Used:[]
# Place:None
# Geoe:False
#
# Tweet 613:
# Username:Nishtelrooy
# Description:30. London. Tough Mudder.
# Location:
# Following Count:235
# Follower Count:103
# Total Tweets:4323
# Retweet Count:0
# Tweet Text:@TLRailUK why was the 00:27 from Farringdon to Three Bridges cancelled 15 minutes after the departure time? Surely you know this before the time so why give us the wrong news and force us to find alternative ways to get home? Why were station staff laughing at us? #thameslink
# Hashtags Used:['thameslink']
# Place:None
# Geoe:True
# Scraping has completed!
